# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as py

# %%
data = pd.read_csv("athlete_events.csv")

# %%
data.Season.value_counts()
# Out:
# Summer    222552
# Winter     48564
# Name: Season, dtype: int64

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
data.drop(data[data.Season == 'Winter'].index, inplace=True)

# %%
data
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
data.drop(data[data.Year < 2000].index, inplace = True)

# %%
data.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age           3
# Height      654
# Weight      905
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     57457
# dtype: int64

# %%
data
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 1            2                      A Lamusi   M  23.0   170.0    60.0
# 31          12             Jyri Tapani Aalto   M  31.0   172.0    70.0
# 33          13            Minna Maarit Aalto   F  34.0   159.0    55.5
# 57          18          Timo Antero Aaltonen   M  31.0   189.0   130.0
# 79          21     Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# ...        ...                           ...  ..   ...     ...     ...
# 271105  135565      Fernando scar Zylberberg   M  23.0   168.0    76.0
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#              Team  NOC        Games  Year  Season            City       Sport  \
# ...

# %%
data.Height.describe()
# Out:
# count    66820.000000
# mean       176.112451
# std         11.455967
# min        133.000000
# 25%        168.000000
# 50%        176.000000
# 75%        184.000000
# max        226.000000
# Name: Height, dtype: float64

# %%
data.Event.value_counts().head(60)
# Out:
# Football Men's Football                            1337
# Hockey Men's Hockey                                 971
# Hockey Women's Hockey                               895
# Football Women's Football                           888
# Handball Men's Handball                             881
# Handball Women's Handball                           813
# Water Polo Men's Water Polo                         769
# Cycling Men's Road Race, Individual                 729
# Basketball Men's Basketball                         717
# Volleyball Men's Volleyball                         712
# Basketball Women's Basketball                       711
# Volleyball Women's Volleyball                       703
# Baseball Men's Baseball                             574
# Athletics Men's Marathon                            556
# Athletics Women's Marathon                          490
# Water Polo Women's Water Polo                       488
# Athletics Men's 4 x 100 metres Relay                436
# ...

# %%
swimming
basketball
hockey
football
athletics
weightlifting
gymnastics
water polo
tennis
archery
badminton
